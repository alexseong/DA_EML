# %% [markdown]
# # PYTHON BEGINNER

# %% [markdown]
# ## BASIC DATA TYPES

# %%
x = 20
type(x)
# Out:
# int

# %%
'''
Multi-line comments go between 3 quotation marks.
You can use single or double quotes.
'''
# One-line comments are preceded by the pound symbol
x = 5               # creates an object
type(x)       # check the type: int (not declared explicitly)
# Out:
# int

# %%
type(x)             # automatically prints
# Out:
# int

# %%
type(5)             # assigning it to a variable is not required
# Out:
# int

# %%
type(5.0)           # float
# Out:
# float

# %%
type('five')        # str
# Out:
# str

# %%
type(True)          # bool
# Out:
# bool

# %%
nums = [5, 5.0, 'five']     # multiple data types
print (nums)                      # print the list
# Out:
# [5, 5.0, 'five']

# %%
type(nums)                  # check the type: list
# Out:
# list

# %%
len(nums)                   # check the length: 3
# Out:
# 3

# %%
nums[0]                     # print first element
# Out:
# 5

# %%
nums[0] = 6                 # replace a list element

# %%
nums
# Out:
# [6, 5.0, 'five']

# %%
nums.append(7)              # list 'method' that modifies the list

# %%
nums
# Out:
# [6, 5.0, 'five', 7]

# %%
len(nums)
# Out:
# 4

# %%
help(nums)                  # help on a list object
# Out:
# Help on list object:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.n
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(...)
#  |      L.__reversed__() -- return a reverse iterator over the list
#  |
#  |  __rmul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      L.__sizeof__() -- size of L in memory, in bytes
#  |
#  |  append(...)
#  |      L.append(object) -> None -- append object to end
#  |
#  |  clear(...)
#  |      L.clear() -> None -- remove all items from L
#  |
#  |  copy(...)
#  |      L.copy() -> list -- a shallow copy of L
#  |
#  |  count(...)
#  |      L.count(value) -> integer -- return number of occurrences of value
#  |
#  |  extend(...)
#  |      L.extend(iterable) -> None -- extend list by appending elements from the iterable
#  |
#  |  index(...)
#  |      L.index(value, [start, [stop]]) -> integer -- return first index of value.
#  |      Raises ValueError if the value is not present.
#  |
#  |  insert(...)
#  |      L.insert(index, object) -- insert object before index
#  |
#  |  pop(...)
#  |      L.pop([index]) -> item -- remove and return item at index (default last).
#  |      Raises IndexError if list is empty or index is out of range.
#  |
#  |  remove(...)
#  |      L.remove(value) -> None -- remove first occurrence of value.
#  |      Raises ValueError if the value is not present.
#  |
#  |  reverse(...)
#  |      L.reverse() -- reverse *IN PLACE*
#  |
#  |  sort(...)
#  |      L.sort(key=None, reverse=False) -> None -- stable sort *IN PLACE*
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
nums.remove('five')         # another list method

# %%
nums
# Out:
# [6, 5.0, 7]

# %%
sorted(nums)                # 'function' that does not modify the list
nums                        # it was not affected
# Out:
# [6, 5.0, 7]

# %%
nums2 = [5.0, 7.0, 4.0, 6.0]
sorted(nums2)
# Out:
# [4.0, 5.0, 6.0, 7.0]

# %%
nums = sorted(nums)         # overwrite the original list
sorted(nums, reverse=True)  # optional argument
# Out:
# [7, 6, 5.0]

# %% [markdown]
# ## FUNCTIONS

# %%
def give_me_five():         # function definition ends with colon
    return 5                # indentation required for function body

# %%
print (give_me_five())
# Out:
# 5

# %%
give_me_five()              # prints the return value (5)
num = give_me_five()        # assigns return value to a variable, doesn't print it
print (num)
# Out:
# 5

# %%
# A function that takes two parameters (hours and rate), and
# returns the total pay.
def compute_pay(hours, rate):
    return hours * rate

# %%
pay = compute_pay(40, 300)
print (pay)
# Out:
# 12000

# %%
def calc(x, y, op="None"):         # three parameters (without any defaults)
    if op == 'add':         # conditional statement
        return x + y
    elif op == 'subtract':
        return x - y
    elif op == 'multiply':
        return x * y
    else:
        print ('Valid operations: add, subtract, multiply')

# %%
val = calc(10, 20)
val
# Out:
# Valid operations: add, subtract, multiply

# %%
val = calc(5, 3, 'add')
val
# Out:
# 8

# %%
val = calc(5, 3, 'subtract')
val
# Out:
# 2

# %%
val = calc(5, 3, 'divide')
val
# Out:
# Valid operations: add, subtract, multiply

# %%
val = calc(5, 3)
val
# Out:
# Valid operations: add, subtract, multiply

# %% [markdown]
# ## FOR LOOPS

# %%
# print each list element in uppercase
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print (fruit.upper())
# Out:
# APPLE
# BANANA
# CHERRY

# %%
print (fruit)
# Out:
# cherry

# %% [markdown]
# # PYTHON INTERMEDIATE

# %% [markdown]
# ## LISTS

# %%
# creating
a = [1, 2, 3, 4, 5]     # create lists using brackets

# %%
# slicing
a[0]        # returns 1 (Python is zero indexed)
# Out:
# 1

# %%
a[2:4]      # returns [2, 3] (inclusive of first index but exclusive of second)
# Out:
# [3, 4]

# %%
a[-1]       # returns 5 (last element)
# Out:
# 5

# %%
# appending
a[5] = 6        # error because you can't assign outside the existing range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-35dab1ae6081> in <module>()
#       1 # appending
# ----> 2 a[5] = 6        # error because you can't assign outside the existing range
#
# IndexError: list assignment index out of range

# %%
a.append(6)     # list method that appends 6 to the end

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = a + [0, 2, 3, 33, 33, 4]     # use plus sign to combine lists

# %%
# checking length
len(a)      # returns 7
# Out:
# 12

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 0, 2, 3, 33, 33, 4]

# %%
# checking type
type(a)     # returns list
# Out:
# list

# %%
type(a[0])  # returns int
# Out:
# int

# %%
# sorting
sorted(a)               # sorts the list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
sorted(a, reverse=True) # reverse=True is an 'optional argument'
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
sorted(a, reverse=True)         # error because optional arguments must be named
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# ## STRINGS

# %%
# creating
a = 'hello'     # can use single or double quotes

# %%
a
# Out:
# 'hello'

# %%
# slicing
a[0]        # returns 'h' (works like list slicing)
# Out:
# 'h'

# %%
a[1:3]      # returns 'el'
# Out:
# 'el'

# %%
a[-1]       # returns 'o'
# Out:
# 'o'

# %%
# concatenating
a + ' there'        # use plus sign to combine strings
# Out:
# 'hello there'

# %%
5 + ' there'        # error because they are different types
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-71c38dfad821> in <module>()
# ----> 1 5 + ' there'        # error because they are different types
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(5) + ' there'   # cast 5 to a string in order for this to work
# Out:
# '5 there'

# %%
x = '5'
int(x)
# Out:
# 5

# %%
a[0]
# Out:
# 'h'

# %%
a.upper()
# Out:
# 'HELLO'

# %%
# uppercasing
a[0] = 'H'      # error because strings are immutable (can't overwrite characters)
a.upper()       # string method (this method doesn't exist for lists)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-814ca77c8939> in <module>()
#       1 # uppercasing
# ----> 2 a[0] = 'H'      # error because strings are immutable (can't overwrite characters)
#       3 a.upper()       # string method (this method doesn't exist for lists)
#
# TypeError: 'str' object does not support item assignment

# %%
# checking length
len(a)      # returns 5 (number of characters)
# Out:
# 5

# %% [markdown]
# ### EXERCISE
# 1. Create a list of the first names of your family members.
# 2. Print the name of the last person in the list.
# 3. Print the length of the name of the first person in the list.
# 4. Change one of the names from their real name to their nickname.
# 5. Append a new person to the list.
# 6. Change the name of the new person to lowercase using the string method 'lower'.
# 7. Sort the list in reverse alphabetical order.
#
# Bonus: Sort the list by the length of the names (shortest to longest).

# %% [markdown]
# ## FOR LOOPS AND LIST COMPREHENSIONS

# %%
nums = [1 ,2, 3, 4, 5, 66, 77, 88, 109]

# %%
# for loop to print 1 through 5
nums = range(1, 6)      # create a list of 1 through 5
for num in nums:        # num 'becomes' each list element for one loop
    print (num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# for loop to print 1, 3, 5
other = [1, 3, 5]       # create a different list
for x in other:         # name 'x' does not matter, not defined in advance
    print (x)             # this loop only executes 3 times (not 5)
# Out:
# 1
# 3
# 5

# %%
nums
# Out:
# range(1, 6)

# %%
# for loop to create a list of 2, 4, 6, 8, 10
doubled = []                # create empty list to store results
for num in nums:            # loop through nums (will execute 5 times)
    doubled.append(num*2)   # append the double of the current value of num

# %%
doubled
# Out:
# [2, 4, 6, 8, 10]

# %%
# equivalent list comprehension
doubled = [num*2 for num in nums ]   # expression (num*2) goes first, brackets
# indicate we are storing results in a list

# %%
doubled
# Out:
# [2, 4, 6, 8, 10]

# %%
# for loop to create a list of 2, 4, 6, 8, 10
doubled2 = []                # create empty list to store results
for num in nums:            # loop through nums (will execute 5 times)
    if num == 2:
        doubled2.append(num*2)   # append the double of the current value of num

# %%
doubled2
# Out:
# [4]

# %% [markdown]
# ### EXERCISE
# 1. Given that: letters = ['a', 'b', 'c']
# 2. Write a list comprehension that returns: ['A', 'B', 'C']

# %%
letters = ['a', 'b', 'c']

# %%
new_list = []
for letter in letters:
    new_list.append(letter.upper())
print (new_list)
# Out:
# ['A', 'B', 'C']

# %%
upper_letters = [letter.upper() for letter in letters]
print (upper_letters)
# Out:
# ['A', 'B', 'C']

# %% [markdown]
# ### EXERCISE
# 1. Given that: word = 'abc'
# 2. Write a list comprehension that returns: ['A', 'B', 'C']

# %%
word = 'abc'
upper_letters = [letter.upper() for letter in word]
print (upper_letters)
# Out:
# ['A', 'B', 'C']

# %%
type(letters)
# Out:
# list

# %% [markdown]
# ### EXERCISE
# 1. Given that: fruits = ['Apple', 'Banana', 'Cherry']
# 2. Write a list comprehension that returns: ['A', 'B', 'C']

# %%
fruits = ['Apple', 'Banana', 'Cherry']
upper_letters = [fruit[0] for fruit in fruits]
print (upper_letters)
# Out:
# ['A', 'B', 'C']

# %% [markdown]
# ## DICTIONARIES

# %%
# dictionaries are made of key-value pairs (like a real dictionary)
family = {'dad':'Homer', 'mom':'Marge', 'size':2}

# %%
# check the length
len(family)         # returns 3 (number of key-value pairs)
# Out:
# 3

# %%
family
# Out:
# {'dad': 'Homer', 'mom': 'Marge', 'size': 2}

# %%
# use the key to look up a value (fast operation regardless of dictionary size)
family['dad']       # returns 'Homer'
# Out:
# 'Homer'

# %%
# can't use a value to look up a key
family['Homer']     # error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-13bc9d28794e> in <module>()
#       1 # can't use a value to look up a key
# ----> 2 family['Homer']     # error
#
# KeyError: 'Homer'

# %%
# dictionaries are unordered
family[0]           # error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-8c1070e8eeb8> in <module>()
#       1 # dictionaries are unordered
# ----> 2 family[0]           # error
#
# KeyError: 0

# %%
# add a new entry
family['cat'] = 'snowball'

# %%
# keys must be unique, so this edits an existing entry
family['cat'] = 'snowball ii'

# %%
family['cat'] = 'meow'

# %%
family
# Out:
# {'cat': 'meow', 'dad': 'Homer', 'mom': 'Marge', 'size': 2}

# %%
# delete an entry
del family['cat']

# %%
family
# Out:
# {'dad': 'Homer', 'mom': 'Marge', 'size': 2}

# %%
# keys can be strings or numbers or tuples, values can be any type
family['kids'] = ['bart', 'lisa']   # value can be a list

# %%
family
# Out:
# {'dad': 'Homer', 'kids': ['bart', 'lisa'], 'mom': 'Marge', 'size': 2}

# %%
len(family['kids'])
# Out:
# 2

# %%
# accessing a list element within a dictionary
family['kids'][1]   # returns 'bart'
# Out:
# 'lisa'

# %%
# useful methods
family.keys()       # returns list: ['dad', 'kids', 'mom', 'size']
# Out:
# dict_keys(['dad', 'mom', 'size', 'kids'])

# %%
family.values()     # returns list: ['Homer', ['bart', 'lisa'], 'Marge', 2]
# Out:
# dict_values(['Homer', 'Marge', 2, ['bart', 'lisa']])

# %%
family.items()      # returns list of tuples:
                    # [('dad', 'Homer'), ('kids', ['bart', 'lisa']), ('mom', 'Marge'), ('size', 2)]
# Out:
# dict_items([('dad', 'Homer'), ('mom', 'Marge'), ('size', 2), ('kids', ['bart', 'lisa'])])

# %%
for item in family.items():
    print (item[0], item[1])
# Out:
# dad Homer
# mom Marge
# size 2
# kids ['bart', 'lisa']

# %% [markdown]
# ### EXERCISE
# 1. Print the name of the mom.
# 2. Change the size to 5.
# 3. Add 'Maggie' to the list of kids.
# 4. Fix 'bart' and 'lisa' so that the first letter is capitalized.
#
# Bonus: Do this last step using a list comprehension.

# %% [markdown]
# ## REQUESTS

# %%
# import module (make its functions available)
import requests

# %%
# use requests to talk to the web
r = requests.get('https://www.microsoft.com')

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
type(r)         # special 'response' object
# Out:
# requests.models.Response

# %%
r.text          # HTML of web page stored as string
# Out:
# '\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="en-us" dir="ltr">\r\n<head data-info="{&quot;v&quot;:&quot;1.0.6596.36930&quot;,&quot;a&quot;:&quot;5970e66e-2c53-4422-bc94-a262d4431317&quot;,&quot;cn&quot;:&quot;18&quot;,&quot;az&quot;:&quot;{did:97609aa8a96c4b6f988172db92e1f860, rid: 18, sn: marketingsites-wcus-prod, dt: 2018-01-04T04:09:26.2127260Z, bt: 2018-01-22T20:31:00.0000000Z}&quot;,&quot;ddpi&quot;:&quot;1&quot;,&quot;dpio&quot;:&quot;&quot;,&quot;dpi&quot;:&quot;1&quot;,&quot;dg&quot;:&quot;uplevel.web.pc&quot;,&quot;th&quot;:&quot;default&quot;,&quot;m&quot;:&quot;en-us&quot;,&quot;l&quot;:&quot;en-us&quot;,&quot;mu&quot;:&quot;en-us&quot;,&quot;rp&quot;:&quot;/en-us/&quot;,&quot;f&quot;:&quot;xboxcontentondesktop,openxbl&quot;}">\r\n        <meta charset="UTF-8" />\r\n\r\n    <meta http-equiv="x-ua-compatible" content="ie=edge" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\r\n    <title>Microsoft - Official Home Page</title>\r\n    \r\n                    <meta name="twitter:url" content="https://www.microsoft.com/en-us" />\r\n                     <meta property="og:url" content="https://www.microsoft.com/en-us" />\r\n                    <meta name="twitter:title" content="Microsoft - Official Home Page" />\r\n                     <meta property="og:title" content="Microsoft - Official Home Page" />\r\n                    <meta name="twitter:description" content="At Microsoft our mission and values are to help people and businesses throughout the world realize their full potential." />\r\n                     <meta property="og:description" content="At Microsoft our mission and values are to help people and businesses throughout the world realize their full potential." />\r\n                    <meta name="twitter:card" content="summary" />\r\n                     <meta property="og:type" content="website" />\r\n        <meta name="description" content="At Microsoft our mission and values are to help people and businesses throughout the world realize their full potential."/>\r\n\r\n\r\n    <link rel="SHORTCUT ICON" href="https://c.s-microsoft.com/favicon.ico?v2" type="image/x-icon"/>\r\n\r\n\r\n        <link rel="dns-prefetch" href="//statics-marketingsites-wcus-ms-com.akamaized.net" />\r\n        <link rel="preconnect" href="//statics-marketingsites-wcus-ms-com.akamaized.net" />\r\n        <link rel="dns-prefetch" href="https://assets.onestore.ms" />\r\n        <link rel="preconnect" href="https://assets.onestore.ms" />\r\n        <link rel="dns-prefetch" href="https://web.vortex.data.microsoft.com" />\r\n        <link rel="preconnect" href="https://web.vortex.data.microsoft.com" />\r\n        <link rel="dns-prefetch" href="https://mem.gfx.ms" />\r\n        <link rel="preconnect" href="https://mem.gfx.ms" />\r\n        <link rel="dns-prefetch" href="https://img-prod-cms-rt-microsoft-com.akamaized.net" />\r\n        <link rel="preconnect" href="https://img-prod-cms-rt-microsoft-com.akamaized.net" />\r\n        <link rel="dns-prefetch" href="https://microsoftwindows.112.2o7.net" />\r\n        <link rel="preconnect" href="https://microsoftwindows.112.2o7.net" />\r\n\r\n    <link rel="preload" as="font" crossorigin="crossorigin" type="font/woff" href="https://assets.onestore.ms/cdnfiles/external/mwf/long/v1/v1.30.0/fonts/MWFMDL2.woff">    \r\n\r\n\r\n    <link rel="canonical" href="https://www.microsoft.com/en-us"/>\r\n\r\n\r\n    \r\n    <link rel="stylesheet" href="//statics-marketingsites-wcus-ms-com.akamaized.net/west-european/mscomhp/_scrf/css/themes=default.device=uplevel_web_pc/a8-9f120f/5b-bf3b1b/e3-f70fa9/d6-7ebcc1/63-a2260c/7c-5c5c89/f1-8f9bf1/fb-a955e4/bc-c437ee/d6-668ada/dd-34ccab/54-76c359/35-88d8f6/9a-221f40/99-2a9dc6/e0-d6e08a/9a-a424ae/10-cb466b/64-1f7454/1f-274d37?ver=2.0" type="text/css" media="all" />\r\n    <style>.productplacementchoice .c-choice-summary{min-width:auto;padding-right:12px}.productplacementchoice .c-choice-summary a{padding:0 36px 0 0;margin:0;color:#0 ...

# %%
type(r.text)    # string is encoded as unicode
# Out:
# str

# %%
r.text[0]       # string can be sliced like any string
# Out:
# '\r'

# %% [markdown]
# ## APIs
#
# What is an API?
# - Application Programming Interface
# - Structured way to expose specific functionality and data access to users
# - Web APIs usually follow the "REST" standard
#
# How to interact with a REST API:
# - Make a "request" to a specific URL (an "endpoint"), and get the data back in a "response"
# - Most relevant request method for us is GET (other methods: POST, PUT, DELETE)
# - Response is often JSON format
# - Web console is sometimes available (allows you to explore an API)
#
# ! pip install spotipy

# %%
! pip install spotipy
# Out:
# Collecting spotipy
# Requirement already satisfied: requests>=1.0 in c:\intelpython3\lib\site-packages (from spotipy)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\intelpython3\lib\site-packages (from requests>=1.0->spotipy)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\intelpython3\lib\site-packages (from requests>=1.0->spotipy)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\intelpython3\lib\site-packages (from requests>=1.0->spotipy)
# Requirement already satisfied: certifi>=2017.4.17 in c:\intelpython3\lib\site-packages\certifi-2017.7.27.1-py3.6.egg (from requests>=1.0->spotipy)
# Installing collected packages: spotipy
# Successfully installed spotipy-2.4.4

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# #### Register your Notebook application on Spotify [here](https://developer.spotify.com/my-applications/#!/applications)
#
# 1. Create an Application
# 2. Copy the Client ID, and Client Secret Values.
# 3. Replace the values below with the ones you copied in Step 2

# %%
client_id = '547b4675e30143ccb010c3cf206a361f'
client_secret = '52a9729657e84d40b9f60b40f7f6a766'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
#sp = spotipy.Spotify() # Without Authorization
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) # With Authorization

# %%
# Custom method from one of the examples on https://github.com/plamere/spotipy/tree/master/examples
def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

# %%
results = get_artist('taylor swift')

# %% [markdown]
# ### What exactly does an enumerate do?
#
# `enumerate()` is one of the built-in Python functions. It returns an enumerate object. In our case that object is a list of tuples (immutable lists), each containing a pair of count/index and value. Look at http://docs.python.org/library/functions.html?highlight=enumerate#enumerate

# %%
# example 1
choices = ['pizza', 'pasta', 'salad', 'nachos']
list(enumerate(choices))

# %%
# example 2
family = {'dad':'Homer', 'mom':'Marge', 'size':2}
for k, v in enumerate(family):
    print (k, v)

# %% [markdown]
# ### Let's apply enumerate to Spotify

# %%
results
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#  'followers': {'href': None, 'total': 9379423},
#  'genres': ['dance pop', 'pop', 'pop christmas', 'post-teen pop'],
#  'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#  'id': '06HL4z0CvFAxyc27GXpf02',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/bdaeccb035a8af87b7a70b62217ff5c633ba6c7c',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/cec43c2fb746ea2a0c7546aa3408fe2f94887fe4',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/33bc9128ad82f7d39847b6db6a49d5416502e7e7',
#    'width': 160}],
#  'name': 'Taylor Swift',
#  'popularity': 93,
#  'type': 'artist',
#  'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}

# %%
results = sp.search(q='taylor swift', limit=20)
for i, t in enumerate(results['tracks']['items']):
    print (' ', i, t['name'])
# Out:
#   0 End Game
#   1 Look What You Made Me Do
#   2 ...Ready For It?
#   3 Delicate
#   4 I Don’t Wanna Live Forever (Fifty Shades Darker)
#   5 Gorgeous
#   6 Our Song
#   7 I Did Something Bad
#   8 Don’t Blame Me
#   9 Call It What You Want
#   10 Getaway Car
#   11 Teardrops On My Guitar - Radio Single Remix
#   12 New Year’s Day
#   13 This Is Why We Can’t Have Nice Things
#   14 Dress
#   15 Picture To Burn
#   16 King Of My Heart
#   17 Dancing With Our Hands Tied
#   18 So It Goes...
#   19 Tim McGraw

# %%
from IPython.display import Image
from IPython.display import display
import spotipy

ledzep_tracks = {}

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

#spotify = spotipy.Spotify()
results = sp.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    ledzep_tracks[track['name']] = [track['preview_url'], track['album']['images'][0]['url']]

for track_name, album_details in ledzep_tracks.items():
    print ("Track Name : %s , Preview URL : %s Image URL : %s" % (track_name, album_details[0], album_details[1]))
# Out:
# Track Name : Stairway To Heaven , Preview URL : https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344
# Track Name : Immigrant Song , Preview URL : https://p.scdn.co/mp3-preview/8455599677a13017978dcd3f4b210937f0a16bcb?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/e6e513e68c4eefdfc7bc213b35061c9c30b42dfa
# Track Name : Whole Lotta Love , Preview URL : https://p.scdn.co/mp3-preview/ce11b19a4d2de9976d7626df0717d0073863909c?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/5fa3a6cc1848ea743a293d2088046746d1b09608
# Track Name : Ramble On , Preview URL : https://p.scdn.co/mp3-preview/83383aceb01ea27b0bffdedfaebe55e29b33aca2?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/5fa3a6cc1848ea743a293d2088046746d1b09608
# Track Name : Good Times Bad Times , Preview URL : https://p.scdn.co/mp3-preview/c1f024eb57b569b926c8e68cab0a6056dc7d9654?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/71e6a72a1b3a00d2ddabee9a3e2d5ade3be25409
# Track Name : Black Dog , Preview URL : https://p.scdn.co/mp3-preview/9b76619fd9d563a48d38cc90ca00c3008327b52e?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344
# Track Name : Kashmir , Preview URL : https://p.scdn.co/mp3-preview/13b2c47c98132f80a5ce12d8a4ceb192ba7a4345?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/e9e82cfa89aaeb1f6b1f8756a98e40ccc65e8a01
# Track Name : Rock And Roll , Preview URL : https://p.scdn.co/mp3-preview/e7ea8a13f7caf6942c5447e9cd96aac2a076d85a?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344
# Track Name : Going To California , Preview URL : https://p.scdn.co/mp3-preview/4bdae56c6a9f7a8ec42b753cb7bea2c77ec68f1e?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344
# Track Name : Babe I'm Gonna Leave You , Preview URL : https://p.scdn.co/mp3-preview/e82d356bea5c8244cee4e6d5447b46b87852dc11?cid=547b4675e30143ccb010c3cf206a361f Image URL : https://i.scdn.co/image/71e6a72a1b3a00d2ddabee9a3e2d5ade3be25409

# %%
ledzep_tracks
# Out:
# {"Babe I'm Gonna Leave You": ['https://p.scdn.co/mp3-preview/e82d356bea5c8244cee4e6d5447b46b87852dc11?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/71e6a72a1b3a00d2ddabee9a3e2d5ade3be25409'],
#  'Black Dog': ['https://p.scdn.co/mp3-preview/9b76619fd9d563a48d38cc90ca00c3008327b52e?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344'],
#  'Going To California': ['https://p.scdn.co/mp3-preview/4bdae56c6a9f7a8ec42b753cb7bea2c77ec68f1e?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344'],
#  'Good Times Bad Times': ['https://p.scdn.co/mp3-preview/c1f024eb57b569b926c8e68cab0a6056dc7d9654?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/71e6a72a1b3a00d2ddabee9a3e2d5ade3be25409'],
#  'Immigrant Song': ['https://p.scdn.co/mp3-preview/8455599677a13017978dcd3f4b210937f0a16bcb?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/e6e513e68c4eefdfc7bc213b35061c9c30b42dfa'],
#  'Kashmir': ['https://p.scdn.co/mp3-preview/13b2c47c98132f80a5ce12d8a4ceb192ba7a4345?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/e9e82cfa89aaeb1f6b1f8756a98e40ccc65e8a01'],
#  'Ramble On': ['https://p.scdn.co/mp3-preview/83383aceb01ea27b0bffdedfaebe55e29b33aca2?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/5fa3a6cc1848ea743a293d2088046746d1b09608'],
#  'Rock And Roll': ['https://p.scdn.co/mp3-preview/e7ea8a13f7caf6942c5447e9cd96aac2a076d85a?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344'],
#  'Stairway To Heaven': ['https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344'],
#  'Whole Lotta Love': ['https://p.scdn.co/mp3-preview/ce11b19a4d2de9976d7626df0717d0073863909c?cid=547b4675e30143ccb010c3cf206a361f',
#   'https://i.scdn.co/image/5fa3a6cc1848ea743a293d2088046746d1b09608']}

# %%
# Let's get cover art for one of the albums
image_contents = requests.get('https://i.scdn.co/image/5fa3a6cc1848ea743a293d2088046746d1b09608').content
Image(image_contents, width=250, height=250)

# %%
for x in ledzep_tracks.values():
    print (x)
# Out:
# ['https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344']
# ['https://p.scdn.co/mp3-preview/8455599677a13017978dcd3f4b210937f0a16bcb?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/e6e513e68c4eefdfc7bc213b35061c9c30b42dfa']
# ['https://p.scdn.co/mp3-preview/ce11b19a4d2de9976d7626df0717d0073863909c?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/5fa3a6cc1848ea743a293d2088046746d1b09608']
# ['https://p.scdn.co/mp3-preview/83383aceb01ea27b0bffdedfaebe55e29b33aca2?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/5fa3a6cc1848ea743a293d2088046746d1b09608']
# ['https://p.scdn.co/mp3-preview/c1f024eb57b569b926c8e68cab0a6056dc7d9654?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/71e6a72a1b3a00d2ddabee9a3e2d5ade3be25409']
# ['https://p.scdn.co/mp3-preview/9b76619fd9d563a48d38cc90ca00c3008327b52e?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344']
# ['https://p.scdn.co/mp3-preview/13b2c47c98132f80a5ce12d8a4ceb192ba7a4345?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/e9e82cfa89aaeb1f6b1f8756a98e40ccc65e8a01']
# ['https://p.scdn.co/mp3-preview/e7ea8a13f7caf6942c5447e9cd96aac2a076d85a?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344']
# ['https://p.scdn.co/mp3-preview/4bdae56c6a9f7a8ec42b753cb7bea2c77ec68f1e?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/557a6058e3de72bf37ffcd2c12dd5932276df344']
# ['https://p.scdn.co/mp3-preview/e82d356bea5c8244cee4e6d5447b46b87852dc11?cid=547b4675e30143ccb010c3cf206a361f', 'https://i.scdn.co/image/71e6a72a1b3a00d2ddabee9a3e2d5ade3be25409']

# %%
# Now let's iterate through all the albums, gather the url's for the images into a list. 
cover_arts = [Image(requests.get(x[1]).content, width=250, height=250) for x in ledzep_tracks.values()]

# View the items in the cover_arts list
print (cover_arts) # each item in the list contains an Image object

# Apply a splat operator (*) to scatter the items in the list. 
display(*cover_arts)
# Out:
# [<IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>, <IPython.core.display.Image object>]
